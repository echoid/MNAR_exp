# %%
import numpy as np
import sys
sys.path.append("..")
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm
import sys

from missing_process.block_rules import *
import json
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import os
from tqdm import tqdm

# %%
real_datalist = ["banknote","concrete_compression",
            "wine_quality_white","wine_quality_red",
            "california","climate_model_crashes",
            "connectionist_bench_sonar","qsar_biodegradation",
            "yeast","yacht_hydrodynamics"
            ]



missingtypelist = ["quantile","diffuse","logistic"]
#missingtypelist = ["logistic"]

seed = 1
nfold = 5

# %%
model_list = ["mean","knn","hyper","gain","XGB","mice","mf","missforest","notmiwae","miwae","tabcsdi","ot"]

# %%
for missing_type in missingtypelist:
    for data_name in real_datalist:
        for model_name in model_list:
            path = f"../results/{missing_type}/{data_name}/{model_name}"

            rmse_path = f"{path}/{missing_type}_RMSE.csv"

            

            try:
                files = os.listdir(path)
                if not os.path.isfile(rmse_path):
                    print("No RMSE")
                elif len([file for file in files if file.endswith("_0.csv")]) == 0:
                    print("No First ML",path)
                elif len([file for file in files if file.endswith("_1.csv")]) == 0:
                    print("No Second ML",path)
                elif len([file for file in files if file.endswith("_2.csv")]) == 0:
                    print("No third ML",path)
            except:
                print(path)
            # for file in csv_files:
            #     file_path = os.path.join(path, file)
            #     os.remove(file_path)
            #     print(f"Deleted: {file_path}")
# Out:
# ../results/quantile/wine_quality_white/tabcsdi
# No First ML ../results/quantile/california/XGB
# ../results/quantile/california/tabcsdi
# ../results/diffuse/california/tabcsdi
# ../results/logistic/california/tabcsdi

# %%
def load_origin_data(missingtypelist,datalist_name):
    '''
    create density plot
    '''
    

    if datalist_name == "real":
        datalist = real_datalist
    elif datalist_name == "syn":
        datalist = syn_datalist

    for missingtype in missingtypelist:
        if missingtype == "logistic":
            missing_rule = load_json_file("missing_rate.json")
        elif missingtype == "diffuse":
            missing_rule = load_json_file("diffuse_ratio.json")
        elif missingtype == "quantile":
            missing_rule = load_json_file("quantile_full.json")

        # load data and its mask
        for dataname in datalist:
            directory_path = f"../datasets/{dataname}"    
            norm_values = np.load(f'{directory_path}/{dataname}_norm.npy')
            
            print(dataname)


            for rule_name in missing_rule:
                observed_masks = np.load(f'{directory_path}/{missingtype}/{rule_name}.npy')


            return norm_values,observed_masks

# %%
def RMSE(mask,complete,imputed):
    missing_data_points = mask == 0

    # Extracting the originally missing data from both complete and imputed data
    original_values = complete[missing_data_points]
    imputed_values = imputed[missing_data_points]

    # Calculating RMSE
    rmse = np.sqrt(np.mean((original_values - imputed_values) ** 2))

    return rmse


def MAE(mask,complete,imputed):
    missing_data_points = mask == 0

    # Extracting the originally missing data from both complete and imputed data
    original_values = complete[missing_data_points]
    imputed_values = imputed[missing_data_points]

    # Calculating RMSE
    mae = np.mean(np.abs(original_values - imputed_values))

    return mae

# %%
def load_impute_data(missingtype,model_name,rule_name,dataname,fold,seed = 1):

    train_impute = np.load(f'../impute/{missingtype}/{dataname}/{model_name}/{rule_name}_seed-{seed}_{fold}_train.npy')
    test_impute = np.load(f'../impute/{missingtype}/{dataname}/{model_name}/{rule_name}_seed-{seed}_{fold}_test.npy')
    return train_impute,test_impute

def load_train_test(index_file,norm_values,observed_masks):  

    train_index = index_file["train_index"]
    test_index = index_file["test_index"]

    train_values = norm_values[train_index,:]

    train_masks = observed_masks[train_index,:]

    test_values = norm_values[test_index,:]

    test_masks = observed_masks[test_index,:]

    return train_values,train_masks,test_values,test_masks

# %%
#datalist = real_datalist
datalist = syn_datalist
model_name = "tabcsdi"
plot = False

missingtypelist = ["logistic"]


for missingtype in missingtypelist:
    if missingtype == "logistic":
        missing_rule = load_json_file("missing_rate.json")
    elif missingtype == "diffuse":
        missing_rule = load_json_file("diffuse_ratio.json")
    elif missingtype == "quantile":
        missing_rule = load_json_file("quantile_full.json")

    # load data and its mask
    for dataname in tqdm(datalist):
        directory_path = f"../datasets/{dataname}"    
        norm_values = np.load(f'{directory_path}/{dataname}_norm.npy')
        f = open(f'{directory_path}/split_index_cv_seed-{seed}_nfold-{nfold}.json')
        index_file = json.load(f)
        print(dataname)

        train_rmse_mean = []
        train_rmse_std = []
        train_mae_mean = []
        train_mae_std = []

        
        test_rmse_mean = []
        test_rmse_std = []
        test_mae_mean = []
        test_mae_std = []


        for rule_name in tqdm(missing_rule):
            observed_masks = np.load(f'{directory_path}/{missingtype}/{rule_name}.npy')
            train_rmse_list = []
            train_mae_list = []
            test_rmse_list = []
            test_mae_list = []
            for fold in index_file:
                index = index_file[fold]
                train_values,train_masks,test_values,test_masks = load_train_test(index,norm_values,observed_masks)
                impute_train,impute_test  = load_impute_data(missingtype,model_name,rule_name,dataname,fold)

                train_rmse = RMSE(train_masks,train_values,impute_train)
                train_mae = MAE(train_masks,train_values,impute_train)

                test_rmse = RMSE(test_masks,test_values,impute_test)
                test_mae = MAE(test_masks,test_values,impute_test)

                train_rmse_list.append(train_rmse)
                train_mae_list.append(train_mae)
                test_rmse_list.append(test_rmse)
                test_mae_list.append(test_mae)
            
            if train_rmse > 0.5 and plot:
                print(rule_name)
                rmse = RMSE_columnwise(train_masks,train_values,impute_train)
                print(rmse)
                make_plot(train_values,impute_train,train_masks,title = f"{model_name} {dataname} {missingtype} {rule_name}",subtitle=rmse)
            
            
                

            train_rmse_mean.append(np.mean(train_rmse_list))
            train_rmse_std.append(np.std(train_rmse_list))

            train_mae_mean.append(np.mean(train_mae_list))
            train_mae_std.append(np.std(train_mae_list))

            test_rmse_mean.append(np.mean(test_rmse_list))
            test_rmse_std.append(np.std(test_rmse_list))

            test_mae_mean.append(np.mean(test_mae_list))
            test_mae_std.append(np.std(test_mae_list))


        df = pd.DataFrame({
        "train_rmse_mean": train_rmse_mean,
        "train_rmse_std":train_rmse_std,

        "train_mae_mean": train_mae_mean,
        "train_mae_std": train_mae_std,

        "test_rmse_mean": test_rmse_mean,
        "test_rmse_std": test_rmse_std,

        "test_mae_mean": test_mae_mean,
        "test_mae_std": test_mae_std
    },index = [rule_name for rule_name in missing_rule])
        
        path = f"../results/{missingtype}/{dataname}/{model_name}"
        if not os.path.exists(path):
            # If the path does not exist, create it
            os.makedirs(path)
        
        df.to_csv(f'{path}/{missingtype}_RMSE.csv')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# syn1
# 100%|██████████| 9/9 [00:00<00:00, 38.95it/s]
# 100%|██████████| 1/1 [00:00<00:00,  4.20it/s]

# %%
def RMSE_columnwise(mask, complete, imputed):


    # Initializing an array to store RMSE for each column
    rmse_per_column = np.zeros(complete.shape[1])

    # Iterate over each column
    for i in range(complete.shape[1]):
        missing_data_points = mask[:, i] == 0
        # Extracting the originally missing data from both complete and imputed data
        original_values = complete[missing_data_points, i]
        imputed_values = imputed[missing_data_points, i]

        # Calculating RMSE for this column
        rmse_per_column[i] = np.sqrt(np.mean((original_values - imputed_values) ** 2))

    return np.nan_to_num(rmse_per_column, nan=0)

# %%
def make_plot(norm_value,impute,mask, title = None,subtitle = None):

    indices = np.argsort(subtitle)[-8:]

    # Sorting the indices and converting to a list
    sorted_indices = np.sort(indices).tolist()

        # Create a 4x2 grid of subplots
    fig, axes = plt.subplots(4, 2, figsize=(12, 12))
    axes = axes.ravel()  # Flatten the 4x2 grid for easy iteration

    impute_value = impute
    nan_mask = np.where(mask == 0, np.nan, mask)
    masked_value_na = norm_value * nan_mask
    
    

    for i in range(len(sorted_indices)):
        norm_column = norm_value[:, sorted_indices[i]]
        impute_column = impute_value[:, sorted_indices[i]]
        mask_column_na = masked_value_na[:, sorted_indices[i]]

        
        bins = np.histogram_bin_edges([norm_column, impute_column], bins='auto')
        #data_column2 = array_list[1][i]
        # Histogram
        #axes[i].hist(data_column, bins=30, alpha=0.7, edgecolor='black',kde = True)
        sns.histplot(data=norm_column, bins=bins, color='orange',alpha = 0.4, ax=axes[i], kde=True, label='Complete Data',
                     #hatch="", 
                     fill=False
                     )
        sns.histplot(data=mask_column_na, bins=bins, color='blue',alpha = 0.1, ax=axes[i], kde=True, label='Observed Data',
                     #hatch="/", 
                     #fill=False
                     )
        sns.histplot(data=impute_column, bins=bins, color='green',alpha = 0.6, ax=axes[i], kde=True, label='Imputed Data',
                     hatch='...', 
                     fill=False
                     )
        axes[i].set_xlabel('Value')
        axes[i].set_ylabel('Frequency')
        if subtitle[i]:
            axes[i].set_title(f'Histogram for Column {sorted_indices[i]+1} RMSE: {subtitle[i]}')
        else:
            axes[i].set_title(f'Histogram for Column {sorted_indices[i]+1}')
        axes[i].legend()

    if title is not None:
        fig.suptitle(title, fontsize=16)
        # Adjust the layout
    plt.tight_layout()
    plt.savefig(f"../plot/{title}.png")
    plt.show()

# %%
def calculate_rmse(missingtype,dataname,model_name,missing_rule):
    # load data and its mask
    directory_path = f"../datasets/{dataname}"    
    norm_values = np.load(f'{directory_path}/{dataname}_norm.npy')
    f = open(f'{directory_path}/split_index_cv_seed-{seed}_nfold-{nfold}.json')
    index_file = json.load(f)

    train_rmse_mean = []
    train_rmse_std = []
    train_mae_mean = []
    train_mae_std = []

    
    test_rmse_mean = []
    test_rmse_std = []
    test_mae_mean = []
    test_mae_std = []


    for rule_name in missing_rule:
        observed_masks = np.load(f'{directory_path}/{missingtype}/{rule_name}.npy')
        train_rmse_list = []
        train_mae_list = []
        test_rmse_list = []
        test_mae_list = []
        for fold in index_file:
            index = index_file[fold]
            train_values,train_masks,test_values,test_masks = load_train_test(index,norm_values,observed_masks)
            impute_train,impute_test  = load_impute_data(missingtype,model_name,rule_name,dataname,fold)

            train_rmse = RMSE(train_masks,train_values,impute_train)
            train_mae = MAE(train_masks,train_values,impute_train)

            test_rmse = RMSE(test_masks,test_values,impute_test)
            test_mae = MAE(test_masks,test_values,impute_test)

            train_rmse_list.append(train_rmse)
            train_mae_list.append(train_mae)
            test_rmse_list.append(test_rmse)
            test_mae_list.append(test_mae)
        
        if train_rmse > 0.5 and plot:
            print(rule_name)
            rmse = RMSE_columnwise(train_masks,train_values,impute_train)
            print(rmse)
            make_plot(train_values,impute_train,train_masks,title = f"{model_name} {dataname} {missingtype} {rule_name}",subtitle=rmse)
        
        
            

        train_rmse_mean.append(np.mean(train_rmse_list))
        train_rmse_std.append(np.std(train_rmse_list))

        train_mae_mean.append(np.mean(train_mae_list))
        train_mae_std.append(np.std(train_mae_list))

        test_rmse_mean.append(np.mean(test_rmse_list))
        test_rmse_std.append(np.std(test_rmse_list))

        test_mae_mean.append(np.mean(test_mae_list))
        test_mae_std.append(np.std(test_mae_list))


    df = pd.DataFrame({
    "train_rmse_mean": train_rmse_mean,
    "train_rmse_std":train_rmse_std,

    "train_mae_mean": train_mae_mean,
    "train_mae_std": train_mae_std,

    "test_rmse_mean": test_rmse_mean,
    "test_rmse_std": test_rmse_std,

    "test_mae_mean": test_mae_mean,
    "test_mae_std": test_mae_std
                    },index = [rule_name for rule_name in missing_rule])
    
    path = f"../results/{missingtype}/{dataname}/{model_name}"
    if not os.path.exists(path):
        # If the path does not exist, create it
        os.makedirs(path)
    
    df.to_csv(f'{path}/{missingtype}_RMSE.csv')

    return None

# %%
os.listdir("results/")
# Out:
# ['diffuse', 'logistic', 'quantile']

# %%
os.chdir("evaluation")

# %%
real_datalist = ["banknote","concrete_compression",
            "wine_quality_white","wine_quality_red",
            "california","climate_model_crashes",
            "connectionist_bench_sonar","qsar_biodegradation",
            "yeast","yacht_hydrodynamics"
            ]
datalist = real_datalist
#datalist = syn_datalist
model_list = ["mean","knn","hyper","gain","XGB","mice","mf","missforest","notmiwae","miwae","tabcsdi","ot"]
#model_list = ["mean","knn","hyper","gain","XGB","mice","mf"]
plot = False
missingtypelist = ["quantile","diffuse","logistic"]

for model_name in model_list:
    for missingtype in missingtypelist:
        if missingtype == "logistic":
            missing_rule = load_json_file("missing_rate.json")
        elif missingtype == "diffuse":
            missing_rule = load_json_file("diffuse_ratio.json")
        elif missingtype == "quantile":
            missing_rule = load_json_file("quantile_full.json")

        # load data and its mask
        for dataname in datalist:
            #calculate_rmse(missingtype,dataname,model_name,missing_rule)
            try:
                calculate_rmse(missingtype,dataname,model_name,missing_rule)
                #print("Complete",missingtype,dataname,model_name)
            except:
                print("Missed",missingtype,dataname,model_name)
# Out:
# Missed quantile banknote mean
# Missed quantile concrete_compression mean
# Missed quantile wine_quality_white mean
# Missed quantile wine_quality_red mean
# Missed quantile california mean
# Missed quantile climate_model_crashes mean
# Missed quantile connectionist_bench_sonar mean
# Missed quantile qsar_biodegradation mean
# Missed quantile yeast mean
# Missed quantile yacht_hydrodynamics mean
# Missed diffuse banknote mean
# Missed diffuse concrete_compression mean
# Missed diffuse wine_quality_white mean
# Missed diffuse wine_quality_red mean
# Missed diffuse california mean
# Missed diffuse climate_model_crashes mean
# Missed diffuse connectionist_bench_sonar mean
# Missed diffuse qsar_biodegradation mean
# Missed diffuse yeast mean
# Missed diffuse yacht_hydrodynamics mean
# Missed logistic banknote mean
# Missed logistic concrete_compression mean
# Missed logistic wine_quality_white mean
# Missed logistic wine_quality_red mean
# Missed logistic california mean
# Missed logistic climate_model_crashes mean
# Missed logistic connectionist_bench_sonar mean
# Missed logistic qsar_biodegradation mean
# Missed logistic yeast mean
# Missed logistic yacht_hydrodynamics mean
# Missed quantile banknote knn
# Missed quantile concrete_compression knn
# Missed quantile wine_quality_white knn
# Missed quantile wine_quality_red knn
# Missed quantile california knn
# Missed quantile climate_model_crashes knn
# Missed quantile connectionist_bench_sonar knn
# Missed quantile qsar_biodegradation knn
# Missed quantile yeast knn
# Missed quantile yacht_hydrodynamics knn
# Missed diffuse banknote knn
# Missed diffuse concrete_compression knn
# Missed diffuse wine_quality_white knn
# Missed diffuse wine_quality_red knn
# Missed diffuse california knn
# Missed diffuse climate_model_crashes knn
# Missed diffuse connectionist_bench_sonar knn
# Missed diffuse qsar_biodegradation knn
# Missed diffuse yeast knn
# Missed diffuse yacht_hydrodynamics knn
# Missed logistic banknote knn
# Missed logistic concrete_compression knn
# Missed logistic wine_quality_white knn
# Missed logistic wine_quality_red knn
# Missed logistic california knn
# Missed logistic climate_model_crashes knn
# Missed logistic connectionist_bench_sonar knn
# Missed logistic qsar_biodegradation knn
# Missed logistic yeast knn
# Missed logistic yacht_hydrodynamics knn
# Missed quantile banknote hyper
# Missed quantile concrete_compression hyper
# Missed quantile wine_quality_white hyper
# Missed quantile wine_quality_red hyper
# Missed quantile california hyper
# Missed quantile climate_model_crashes hyper
# Missed quantile connectionist_bench_sonar hyper
# Missed quantile qsar_biodegradation hyper
# Missed quantile yeast hyper
# Missed quantile yacht_hydrodynamics hyper
# Missed diffuse banknote hyper
# Missed diffuse concrete_compression hyper
# Missed diffuse wine_quality_white hyper
# Missed diffuse wine_quality_red hyper
# Missed diffuse california hyper
# Missed diffuse climate_model_crashes hyper
# Missed diffuse connectionist_bench_sonar hyper
# Missed diffuse qsar_biodegradation hyper
# Missed diffuse yeast hyper
# Missed diffuse yacht_hydrodynamics hyper
# Missed logistic banknote hyper
# Missed logistic concrete_compression hyper
# Missed logistic wine_quality_white hyper
# Missed logistic wine_quality_red hyper
# Missed logistic california hyper
# Missed logistic climate_model_crashes hyper
# Missed logistic connectionist_bench_sonar hyper
# Missed logistic qsar_biodegradation hyper
# Missed logistic yeast hyper
# Missed logistic yacht_hydrodynamics hyper
# Missed quantile banknote gain
# Missed quantile concrete_compression gain
# Missed quantile wine_quality_white gain
# Missed quantile wine_quality_red gain
# Missed quantile california gain
# Missed quantile climate_model_crashes gain
# Missed quantile connectionist_bench_sonar gain
# Missed quantile qsar_biodegradation gain
# Missed quantile yeast gain
# Missed quantile yacht_hydrodynamics gain
# Missed diffuse banknote gain
# Missed diffuse concrete_compression gain
# Missed diffuse wine_quality_white gain
# Missed diffuse wine_quality_red gain
# Missed diffuse california gain
# Missed diffuse climate_model_crashes gain
# Missed diffuse connectionist_bench_sonar gain
# Missed diffuse qsar_biodegradation gain
# Missed diffuse yeast gain
# Missed diffuse yacht_hydrodynamics gain
# Missed logistic banknote gain
# Missed logistic concrete_compression gain
# Missed logistic wine_quality_white gain
# Missed logistic wine_quality_red gain
# Missed logistic california gain
# Missed logistic climate_model_crashes gain
# Missed logistic connectionist_bench_sonar gain
# Missed logistic qsar_biodegradation gain
# Missed logistic yeast gain
# Missed logistic yacht_hydrodynamics gain
# Missed quantile banknote XGB
# Missed quantile concrete_compression XGB
# Missed quantile wine_quality_white XGB
# Missed quantile wine_quality_red XGB
# Missed quantile california XGB
# Missed quantile climate_model_crashes XGB
# Missed quantile connectionist_bench_sonar XGB
# Missed quantile qsar_biodegradation XGB
# Missed quantile yeast XGB
# Missed quantile yacht_hydrodynamics XGB
# Missed diffuse banknote XGB
# Missed diffuse concrete_compression XGB
# Missed diffuse wine_quality_white XGB
# Missed diffuse wine_quality_red XGB
# Missed diffuse california XGB
# Missed diffuse climate_model_crashes XGB
# Missed diffuse connectionist_bench_sonar XGB
# Missed diffuse qsar_biodegradation XGB
# Missed diffuse yeast XGB
# Missed diffuse yacht_hydrodynamics XGB
# Missed logistic banknote XGB
# Missed logistic concrete_compression XGB
# Missed logistic wine_quality_white XGB
# Missed logistic wine_quality_red XGB
# Missed logistic california XGB
# Missed logistic climate_model_crashes XGB
# Missed logistic connectionist_bench_sonar XGB
# Missed logistic qsar_biodegradation XGB
# Missed logistic yeast XGB
# Missed logistic yacht_hydrodynamics XGB
# Missed quantile banknote mice
# Missed quantile concrete_compression mice
# Missed quantile wine_quality_white mice
# Missed quantile wine_quality_red mice
# Missed quantile california mice
# Missed quantile climate_model_crashes mice
# Missed quantile connectionist_bench_sonar mice
# Missed quantile qsar_biodegradation mice
# Missed quantile yeast mice
# Missed quantile yacht_hydrodynamics mice
# Missed diffuse banknote mice
# Missed diffuse concrete_compression mice
# Missed diffuse wine_quality_white mice
# Missed diffuse wine_quality_red mice
# Missed diffuse california mice
# Missed diffuse climate_model_crashes mice
# Missed diffuse connectionist_bench_sonar mice
# Missed diffuse qsar_biodegradation mice
# Missed diffuse yeast mice
# Missed diffuse yacht_hydrodynamics mice
# Missed logistic banknote mice
# Missed logistic concrete_compression mice
# Missed logistic wine_quality_white mice
# Missed logistic wine_quality_red mice
# Missed logistic california mice
# Missed logistic climate_model_crashes mice
# Missed logistic connectionist_bench_sonar mice
# Missed logistic qsar_biodegradation mice
# Missed logistic yeast mice
# Missed logistic yacht_hydrodynamics mice
# Missed quantile banknote mf
# Missed quantile concrete_compression mf
# Missed quantile wine_quality_white mf
# Missed quantile wine_quality_red mf
# Missed quantile california mf
# Missed quantile climate_model_crashes mf
# Missed quantile connectionist_bench_sonar mf
# Missed quantile qsar_biodegradation mf
# Missed quantile yeast mf
# Missed quantile yacht_hydrodynamics mf
# Missed diffuse banknote mf
# Missed diffuse concrete_compression mf
# Missed diffuse wine_quality_white mf
# Missed diffuse wine_quality_red mf
# Missed diffuse california mf
# Missed diffuse climate_model_crashes mf
# Missed diffuse connectionist_bench_sonar mf
# Missed diffuse qsar_biodegradation mf
# Missed diffuse yeast mf
# Missed diffuse yacht_hydrodynamics mf
# Missed logistic banknote mf
# Missed logistic concrete_compression mf
# Missed logistic wine_quality_white mf
# Missed logistic wine_quality_red mf
# Missed logistic california mf
# Missed logistic climate_model_crashes mf
# Missed logistic connectionist_bench_sonar mf
# Missed logistic qsar_biodegradation mf
# Missed logistic yeast mf
# Missed logistic yacht_hydrodynamics mf
# Missed quantile banknote missforest
# Missed quantile concrete_compression missforest
# Missed quantile wine_quality_white missforest
# Missed quantile wine_quality_red missforest
# Missed quantile california missforest
# Missed quantile climate_model_crashes missforest
# Missed quantile connectionist_bench_sonar missforest
# Missed quantile qsar_biodegradation missforest
# Missed quantile yeast missforest
# Missed quantile yacht_hydrodynamics missforest
# Missed diffuse banknote missforest
# Missed diffuse concrete_compression missforest
# Missed diffuse wine_quality_white missforest
# Missed diffuse wine_quality_red missforest
# Missed diffuse california missforest
# Missed diffuse climate_model_crashes missforest
# Missed diffuse connectionist_bench_sonar missforest
# Missed diffuse qsar_biodegradation missforest
# Missed diffuse yeast missforest
# Missed diffuse yacht_hydrodynamics missforest
# Missed logistic banknote missforest
# Missed logistic concrete_compression missforest
# Missed logistic wine_quality_white missforest
# Missed logistic wine_quality_red missforest
# Missed logistic california missforest
# Missed logistic climate_model_crashes missforest
# Missed logistic connectionist_bench_sonar missforest
# Missed logistic qsar_biodegradation missforest
# Missed logistic yeast missforest
# Missed logistic yacht_hydrodynamics missforest
# Missed quantile banknote notmiwae
# Missed quantile concrete_compression notmiwae
# Missed quantile wine_quality_white notmiwae
# Missed quantile wine_quality_red notmiwae
# Missed quantile california notmiwae
# Missed quantile climate_model_crashes notmiwae
# Missed quantile connectionist_bench_sonar notmiwae
# Missed quantile qsar_biodegradation notmiwae
# Missed quantile yeast notmiwae
# Missed quantile yacht_hydrodynamics notmiwae
# Missed diffuse banknote notmiwae
# Missed diffuse concrete_compression notmiwae
# Missed diffuse wine_quality_white notmiwae
# Missed diffuse wine_quality_red notmiwae
# Missed diffuse california notmiwae
# Missed diffuse climate_model_crashes notmiwae
# Missed diffuse connectionist_bench_sonar notmiwae
# Missed diffuse qsar_biodegradation notmiwae
# Missed diffuse yeast notmiwae
# Missed diffuse yacht_hydrodynamics notmiwae
# Missed logistic banknote notmiwae
# Missed logistic concrete_compression notmiwae
# Missed logistic wine_quality_white notmiwae
# Missed logistic wine_quality_red notmiwae
# Missed logistic california notmiwae
# Missed logistic climate_model_crashes notmiwae
# Missed logistic connectionist_bench_sonar notmiwae
# Missed logistic qsar_biodegradation notmiwae
# Missed logistic yeast notmiwae
# Missed logistic yacht_hydrodynamics notmiwae
# Missed quantile banknote miwae
# Missed quantile concrete_compression miwae
# Missed quantile wine_quality_white miwae
# Missed quantile wine_quality_red miwae
# Missed quantile california miwae
# Missed quantile climate_model_crashes miwae
# Missed quantile connectionist_bench_sonar miwae
# Missed quantile qsar_biodegradation miwae
# Missed quantile yeast miwae
# Missed quantile yacht_hydrodynamics miwae
# Missed diffuse banknote miwae
# Missed diffuse concrete_compression miwae
# Missed diffuse wine_quality_white miwae
# Missed diffuse wine_quality_red miwae
# Missed diffuse california miwae
# Missed diffuse climate_model_crashes miwae
# Missed diffuse connectionist_bench_sonar miwae
# Missed diffuse qsar_biodegradation miwae
# Missed diffuse yeast miwae
# Missed diffuse yacht_hydrodynamics miwae
# Missed logistic banknote miwae
# Missed logistic concrete_compression miwae
# Missed logistic wine_quality_white miwae
# Missed logistic wine_quality_red miwae
# Missed logistic california miwae
# Missed logistic climate_model_crashes miwae
# Missed logistic connectionist_bench_sonar miwae
# Missed logistic qsar_biodegradation miwae
# Missed logistic yeast miwae
# Missed logistic yacht_hydrodynamics miwae
# Missed quantile banknote tabcsdi
# Missed quantile concrete_compression tabcsdi
# Missed quantile wine_quality_white tabcsdi
# Missed quantile wine_quality_red tabcsdi
# Missed quantile california tabcsdi
# Missed quantile climate_model_crashes tabcsdi
# Missed quantile connectionist_bench_sonar tabcsdi
# Missed quantile qsar_biodegradation tabcsdi
# Missed quantile yeast tabcsdi
# Missed quantile yacht_hydrodynamics tabcsdi
# Missed diffuse banknote tabcsdi
# Missed diffuse concrete_compression tabcsdi
# Missed diffuse wine_quality_white tabcsdi
# Missed diffuse wine_quality_red tabcsdi
# Missed diffuse california tabcsdi
# Missed diffuse climate_model_crashes tabcsdi
# Missed diffuse connectionist_bench_sonar tabcsdi
# Missed diffuse qsar_biodegradation tabcsdi
# Missed diffuse yeast tabcsdi
# Missed diffuse yacht_hydrodynamics tabcsdi
# Missed logistic banknote tabcsdi
# Missed logistic concrete_compression tabcsdi
# Missed logistic wine_quality_white tabcsdi
# Missed logistic wine_quality_red tabcsdi
# Missed logistic california tabcsdi
# Missed logistic climate_model_crashes tabcsdi
# Missed logistic connectionist_bench_sonar tabcsdi
# Missed logistic qsar_biodegradation tabcsdi
# Missed logistic yeast tabcsdi
# Missed logistic yacht_hydrodynamics tabcsdi
# Missed quantile banknote ot
# Missed quantile concrete_compression ot
# Missed quantile wine_quality_white ot
# Missed quantile wine_quality_red ot
# Missed quantile california ot
# Missed quantile climate_model_crashes ot
# Missed quantile connectionist_bench_sonar ot
# Missed quantile qsar_biodegradation ot
# Missed quantile yeast ot
# Missed quantile yacht_hydrodynamics ot
# Missed diffuse banknote ot
# Missed diffuse concrete_compression ot
# Missed diffuse wine_quality_white ot
# Missed diffuse wine_quality_red ot
# Missed diffuse california ot
# Missed diffuse climate_model_crashes ot
# Missed diffuse connectionist_bench_sonar ot
# Missed diffuse qsar_biodegradation ot
# Missed diffuse yeast ot
# Missed diffuse yacht_hydrodynamics ot
# Missed logistic banknote ot
# Missed logistic concrete_compression ot
# Missed logistic wine_quality_white ot
# Missed logistic wine_quality_red ot
# Missed logistic california ot
# Missed logistic climate_model_crashes ot
# Missed logistic connectionist_bench_sonar ot
# Missed logistic qsar_biodegradation ot
# Missed logistic yeast ot
# Missed logistic yacht_hydrodynamics ot

# %%
datalist = [
    "banknote",
        "concrete_compression",
            "wine_quality_white","wine_quality_red",
            "california",
            "climate_model_crashes",
            "connectionist_bench_sonar","qsar_biodegradation",
            "yeast","yacht_hydrodynamics"
            ]


missingtypelist = [
                    "quantile",
                   "diffuse",
                   "logistic"
                   ]
model_list = ["mean","knn","hyper","gain","XGB","mice","mf","missforest","notmiwae","miwae","tabcsdi","ot"]
seed = 1
nfold = 5
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

for model_name in model_list:
    for missingtype in missingtypelist:
        if missingtype == "logistic":
            missing_rule = load_json_file("missing_rate.json")
        elif missingtype == "diffuse":
            missing_rule = load_json_file("diffuse_ratio.json")
        elif missingtype == "quantile":
            missing_rule = load_json_file("quantile_full.json")

        # load data and its mask
        for dataname in datalist:
            if dataname == "california" and model_name =="tabcsdi":
                pass
            else:
            
                directory_path = f"datasets/{dataname}"
                data = dataset_loader(dataname)    
                label_values, task_type = process_target(dataname,data["target"])

                for ml_model_i in range(3):

                    #ml_model = ml_model_list[ml_model_i]
                    path = f"results/{missingtype}/{dataname}/{model_name}"

                    file_path = f'{path}/{missingtype}_{task_type}_{ml_model_i}.csv'

                    if os.path.exists(file_path):
                        pass
                    else:
                        print(f"The file {file_path} does not exist.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 31
#      29     missing_rule = load_json_file("diffuse_ratio.json")
#      30 elif missingtype == "quantile":
# ---> 31     missing_rule = load_json_file("quantile_full.json")
#      33 # load data and its mask
#      34 for dataname in datalist:
#
# NameError: name 'load_json_file' is not defined
