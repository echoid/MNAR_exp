# %%
import numpy as np
from sklearn.impute import KNNImputer
import sys
sys.path.append("..")
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm
import sys
import missing_process.missing_method as missing_method
from missing_process.block_rules import *
from utils import load_train_test,make_plot,RMSE,mask_check
import json
import matplotlib.pyplot as plt
import seaborn as sns

from fancyimpute import MatrixFactorization, SoftImpute
# Out:
# WARNING:tensorflow:From e:\ANACONDA\envs\py3.10\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
real_datalist = ["banknote","concrete_compression",
            "wine_quality_white","wine_quality_red",
            "california","climate_model_crashes",
            "connectionist_bench_sonar","qsar_biodegradation",
            "yeast","yacht_hydrodynamics"
            ]
#real_datalist = ["yacht_hydrodynamics"]

syn_datalist = ["syn1"]


missingtypelist = ["quantile","diffuse","logistic"]
#missingtypelist = ["diffuse"]

# %%
def imputer_model(dataname,missingtype,model_name,imp):
    seed = 1
    nfold = 5

    if missingtype == "logistic":
        missing_rule = load_json_file("missing_rate.json")
    elif missingtype == "diffuse":
        missing_rule = load_json_file("diffuse_ratio.json")
    elif missingtype == "quantile":
        missing_rule = load_json_file("quantile_full.json")

    print(dataname)
    path = f"../impute/{missingtype}/{dataname}/{model_name}"
    if not os.path.exists(path):
        # If the path does not exist, create it
        os.makedirs(path)

    for rule_name in missing_rule:

            directory_path = f"../datasets/{dataname}"  
            # Opening JSON file
            f = open(f'{directory_path}/split_index_cv_seed-{seed}_nfold-{nfold}.json')
            index_file = json.load(f)

            for fold in index_file:

                train_values,train_masks,test_values,test_masks = load_train_test(index_file[fold],missingtype,rule_name,directory_path,dataname)

                train_values_na = np.where(train_masks == 0, np.nan, train_values)
                test_values_na = np.where(test_masks == 0, np.nan, test_values)
                
                
                # imp.fit(train_values_na)
                # test_imp = imp.transform(test_values_na)
                # train_imp = imp.transform(train_values_na)
                
                train_imp = imp.fit_transform(train_values_na)
                test_imp = imp.fit_transform(test_values_na)

                np.save(f'{path}/{rule_name}_seed-{seed}_{fold}_train.npy', train_imp.astype("float32"))
                np.save(f'{path}/{rule_name}_seed-{seed}_{fold}_test.npy', test_imp.astype("float32"))

                if  (test_imp.shape != test_values_na.shape):
                    print("test shape")
                if  (train_imp.shape != train_values_na.shape):
                    print("train shape")

# %%
real_datalist = [
            "banknote",
             "concrete_compression",
             "wine_quality_white",
            "wine_quality_red",
            "california",
            "climate_model_crashes",
            "connectionist_bench_sonar",
            "qsar_biodegradation", 
            "yeast", 
            "yacht_hydrodynamics"
            ]
missingtypelist = ["quantile",
                   "diffuse",
                   "logistic"
                   ]

imp = MatrixFactorization()
for dataname in real_datalist:
    for missing_method in tqdm(missingtypelist):
        imputer_model(dataname,missing_method,"mf",imp)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# banknote
# [MatrixFactorization] Iter 10: observed MAE=0.148596 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.144278 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.132626 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.104391 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.070037 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.158397 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.153067 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.148231 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.141058 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.128506 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.149918 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.144656 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.130156 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.098054 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.066953 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.151257 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.144387 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.139517 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.131883 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.120219 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.151095 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.145665 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.130046 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.099393 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.071491 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.148769 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.144015 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.141407 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.136920 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.130565 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.154160 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.145687 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.127920 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.095432 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.067301 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.145276 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.140586 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.135827 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.130511 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.121149 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.153783 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.146437 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.139377 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.112668 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.078731 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.149008 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.143898 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.139523 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.133186 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.124197 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.154668 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.145577 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.135564 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.110579 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.078108 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.159512 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.153768 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.