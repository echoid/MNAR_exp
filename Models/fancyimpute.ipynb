# %%
from fancyimpute import MatrixFactorization, SoftImpute

import numpy as np
import sys
sys.path.append("..")
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm
import sys
import missing_process.missing_method as missing_method
from missing_process.block_rules import *
from utils import load_train_test,make_plot,RMSE,mask_check
import json
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# WARNING:tensorflow:From e:\ANACONDA\envs\py3.10\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
real_datalist = ["banknote","concrete_compression",
            "wine_quality_white","wine_quality_red",
            "california","climate_model_crashes",
            "connectionist_bench_sonar","qsar_biodegradation",
            "yeast","yacht_hydrodynamics"
            ]
#real_datalist = ["yacht_hydrodynamics"]

syn_datalist = ["syn1"]


missingtypelist = ["quantile","diffuse","logistic"]
#missingtypelist = ["diffuse"]

# %%
def imputer_model(missingtypelist,datalist_name,model_name,seed = 1,nfold = 5):

    if model_name == "mf":
        imp = MatrixFactorization()
    else:
        imp = SoftImpute()

    if datalist_name == "real":
        datalist = real_datalist
    elif datalist_name == "syn":
        datalist = syn_datalist

    for missingtype in missingtypelist:
        print(missingtype)
        if missingtype == "logistic":
            missing_rule = load_json_file("missing_rate.json")
        elif missingtype == "diffuse":
            missing_rule = load_json_file("diffuse_ratio.json")
        elif missingtype == "quantile":
            missing_rule = load_json_file("quantile_full.json")



        for dataname in tqdm(datalist):
            print(dataname)
            path = f"../impute/{missingtype}/{dataname}/{model_name}"
            if not os.path.exists(path):
                # If the path does not exist, create it
                os.makedirs(path)

            for rule_name in tqdm(missing_rule):

                    directory_path = f"../datasets/{dataname}"  
                    # Opening JSON file
                    f = open(f'{directory_path}/split_index_cv_seed-{seed}_nfold-{nfold}.json')
                    index_file = json.load(f)

                    for fold in index_file:

                        train_values,train_masks,test_values,test_masks = load_train_test(index_file[fold],missingtype,rule_name,directory_path,dataname)

                        train_values_na = np.where(train_masks == 0, np.nan, train_values)
                        test_values_na = np.where(test_masks == 0, np.nan, test_values)
                        
                        test_imp = imp.fit_transform(test_values_na)
                        train_imp = imp.fit_transform(train_values_na)


                        np.save(f'{path}/{rule_name}_seed-{seed}_{fold}_train.npy', train_imp.astype("float32"))
                        np.save(f'{path}/{rule_name}_seed-{seed}_{fold}_test.npy', test_imp.astype("float32"))

                        if  (test_imp.shape != test_values_na.shape):
                            print("test shape")
                        if  (train_imp.shape != train_values_na.shape):
                            print("train shape")

# %%
real_datalist = [
            "banknote",
             "concrete_compression",
            #  "wine_quality_white",
            # "wine_quality_red",
            # "california",
            # "climate_model_crashes",
            # "connectionist_bench_sonar",
            # "qsar_biodegradation", 
            # "yeast", 
            # "yacht_hydrodynamics"
            ]
missingtypelist = [#"quantile",
                   #"diffuse",
                   "logistic"
                   ]

imputer_model(missingtypelist,"syn","mf")
# Out:
# logistic
#   0%|          | 0/1 [00:00<?, ?it/s]
# syn1
# [MatrixFactorization] Iter 10: observed MAE=0.168927 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.165364 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.162803 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.159162 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.152753 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.163976 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.159547 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.150462 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.128983 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.099777 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.158606 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.155271 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.152727 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.149002 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.143484 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.167617 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.162072 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.153640 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.131534 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.098928 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.162278 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.158539 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.155637 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.152082 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.146088 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.165884 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.160999 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.153072 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.130048 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.096559 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.170523 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.166952 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.163695 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.158486 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.148869 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.163749 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.159043 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.150306 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.130976 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.100958 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.159297 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.155850 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.153045 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.150204 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.145024 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.164532 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.159542 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.150108 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.128356 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.100220 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.165203 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.159837 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.156709 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.152499 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.146406 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.164084 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.157476 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.151328 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.136028 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.107154 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.159294 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.154266 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.151365 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.148227 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.143534 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.165121 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.160033 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.151990 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.133662 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.105303 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.161955 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.157199 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.154694 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.151170 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.145884 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.164980 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.157811 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.150398 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.132246 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.103115 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.169775 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.166180 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.162951 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.159588 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.152858 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.163404 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.157341 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.150381 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.133354 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.106693 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.156789 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.150976 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.148049 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.144973 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.140261 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.163490 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.158100 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0.151121 rank=40
# [MatrixFactorization] Iter 40: observed MAE=0.134526 rank=40
# [MatrixFactorization] Iter 50: observed MAE=0.104474 rank=40
# [MatrixFactorization] Iter 10: observed MAE=0.168132 rank=40
# [MatrixFactorization] Iter 20: observed MAE=0.162808 rank=40
# [MatrixFactorization] Iter 30: observed MAE=0